# %%
print('Hello', 'world!')
# Out:
# Hello world!

# %%
# 주석데스

# %%
print('"Hello. World!"')
print('"12345x7890"')
# Out:
# "Hello. World!"
# "12345x7890"

# %%
print('"Hello. World!"'); print('"12345x7890"')
# Out:
# "Hello. World!"
# "12345x7890"

# %%
int a = 0; # 에러, 파이썬은 형태선언 안한다. a=0이 맞는 표현 
if a == 10:
    print('10입니다')
# Out:
#   File "<ipython-input-15-d0b76d8135cd>", line 1
#     int a = 0;
#         ^
# SyntaxError: invalid syntax

# %%
a = input("x의 값을 입력하세요 : ")

#형변환 필요가 없습니까?

if a == 10:
    print('10입니다')
elif a != 10 and type(a) is int:
    print('10이 아닙니다')
else :
  print('정수가 아닙니다.')
# Out:
# x의 값을 입력하세요 : sddads
# 정수가 아닙니다.

# %%
a = input("x의 값을 입력하세요 : ");

#형변환 필요가 없습니까?

a = int(a);

#아니오, 형식을 특정 할 경우 필요합니다.

if a == 10:
    print('10입니다');
elif a != 10 and type(a) is int:
    print('10이 아닙니다');
else :
  print('정수가 아닙니다.');
# Out:
# x의 값을 입력하세요 : 10
# 10입니다

# %%
a = input("x의 값을 입력하세요 : ");

#형변환 필요가 없습니까?
#아니오, 형식을 특정 할 경우 필요합니다.

if type(a) is int:
  a = int(a);
# elif type(a) is string: #파이썬은 string 대신 str
elif type(a) is str:
  a = str(a);
else :
  print('알 수 없는 값입니다.')

if a == 10:
    print('10입니다');
elif a != 10 and type(a) is int:
    print('10이 아닙니다');
else :
  print('정수가 아닙니다.');
# Out:
# x의 값을 입력하세요 : 10
# 정수가 아닙니다.

# %%
4.3-2.7
# Out:
# 1.5999999999999996

# %%
print(286.2);
# Out:
# 286.2

# %%
defaltDem = 225;
AP_Coefficient = 0.6;
resultShouldBe = 286.2;
HowMuchAP = round((286.2 - 225) / 0.6);

print("스킬의 기본 데미지는 " + str(defaltDem) + ", AP 계수는 " + str(AP_Coefficient) + ", AP 레벨은 " + str(HowMuchAP) + ", 따라서 총 데미지는?");
print(defaltDem + (AP_Coefficient * HowMuchAP));
# Out:
# 스킬의 기본 데미지는 225, AP 계수는 0.6, AP 레벨은 102, 따라서 총 데미지는?
# 286.2

# %%
#변수 여러개!

x,y,z = 10,20,30
print(x,y,z)
x = y = z = 10
print(x,y,z)
# Out:
# 10 20 30
# 10 10 10

# %%
#변수값 교체
x = 10
y = 20
x,y = y,x
print(x, y)
#대박... 너무편하다...진작 왜 파이썬을 안했을까
# Out:
# 20 10

# %%
#변수 삭제 기능
x = 10
del x
x = 20
print(x);
# Out:
# 20

# %%
a = b = 10
c, d = 20, None

print(a,b,c,d)
# Out:
# 10 10 20 None

# %%
#여러 줄 

hello = """ dd
dd
dd"""
print(hello);
# Out:
#  dd
# dd
# dd

# %%
len(hello)
#9가 나오는 이유는 빈칸과 엔터
# Out:
# 9

# %%
print(hello * 3);
#문자열 반복 기능에서, 이스케이프 문자 제거는 어떻게?
# Out:
#  dd
# dd
# dd dd
# dd
# dd dd
# dd
# dd

# %%
s = "0123456"

print(len(s))
# Out:
# 7

# %%
#print("스킬의 기본 데미지는 " , str(defaltDem) , ", AP 계수는 " + str(AP_Coefficient) , ", AP 레벨은 " + str(HowMuchAP) ,", 따라서 총 데미지는?");
#print(defaltDem, (AP_Coefficient * HowMuchAP));
#더하기 대신 콤마 형식도 가능

print(f"스킬의 기본 데미지는 {str(defaltDem)}, AP 계수는, {str(AP_Coefficient)},  AP 레벨은  {str(HowMuchAP)}.  따라서 총 데미지는?");
print(defaltDem + (AP_Coefficient * HowMuchAP));
# 편리한 형식
# Out:
# 스킬의 기본 데미지는 225, AP 계수는, 0.6,  AP 레벨은  102.  따라서 총 데미지는?
# 286.2

# %%
data = input("값을 입력 : ")
print(data);
# Out:
# 값을 입력 : hey
# hey

# %%
a = float(input(""))
b = float(input(""))

print(a + b)
# Out:
# daads
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-453789cdb271> in <module>
# ----> 1 a = float(input(""))
#       2 b = float(input(""))
#       3
#       4 print(a + b)
#
# ValueError: could not convert string to float: 'daads'

# %%
a,b,c = (input("").split())

print (a)
print (b)
print (c)
# Out:
# 1 2 3
# 1
# 2
# 3

# %%
print(("호 우").split())
# Out:
# ['호', '우']

# %%
"호 우".split()
# Out:
# ['호', '우']

# %%
### 단순 해결

# numStr = input("숫자를 입력하세요: ");

# numChar1, numChar2, numChar3, numChar4, numChar5 = numStr[4], numStr[3], numStr[2], numStr[1], numStr[0]

# numint = int(numChar1 + numChar2 + numChar3 + numChar4 + numChar5)

# print(numint);
# print(numint + 1); #정수 검증

### 코드 단축

numStr = input("숫자를 입력하세요: ");
print(int(numStr[4] + numStr[3] + numStr[2] + numStr[1] + numStr[0]))
# or
# print(int(numStr[-1] + numStr[-2] + numStr[-3] + numStr[-4] + numStr[-5]))
print(int(numStr[4] + numStr[3] + numStr[2] + numStr[1] + numStr[0]) + 1); #정수 검증
# Out:
# 숫자를 입력하세요: 12345
# 54321
# 54322

# %%
a,b = map(int, input('숫자 두 개를 입력하세요: ').split())

print(a+b)
# Out:
# 숫자 두 개를 입력하세요: 30 40
# 70

# %%
a, b = map(int,["111","222"])
print(a + b)
# Out:
# 333

# %%
a,b,c = map(int, input("정수 세개를 입력: ").split())
print(a+b+c);
# Out:
# 정수 세개를 입력: 10 20 30
# 60

# %%
print(1, 2, 3)
print(1, 2, 3, sep=', ')
print(1, 2, 3, sep=',')
# Out:
# 1 2 3
# 1, 2, 3
# 1,2,3

# %%
# 1. 파이썬의 x = None; 과, 자바스크립트의 var x; 는 변수의 자료형 및 값을 선언하지 않습니다. 따라서, 같은 개념인가요? 

# !맞다.

# 2. 파이썬 자료형 변환이 자동으로 되는 것 같은데, 이 부분에 대해서 수동으로 형변환 해주는 것이 맞을까요?
# https://colab.research.google.com/drive/1hA6YqotXcUaNEuzIoqrrECEKW9YHnG4Y#scrollTo=7Wkpa1G__o7y&line=1&uniqifier=1

# !해주는게 맞다.

# 3. 자료형이나 선언, 문법 등에 대해서 제가 취약하고 귀찮아하는 편이지만, 그래서 오히려 신경썼던 부분이기도 합니다. 
#    파이썬은 이런 부분에 대해서 flexible 한 것 같은데, 문법이나 구조에 대해 엄격하게 유지하면서 더 발전하는게 좋을까요? 아니면 마음을 좀 놓고 편하게 하는게 나을까요?

# !편하게 해라.

#    p.s 저는 C, C++ 을 학교에서 잠깐 했으며, 현업에서는 C#, 자바스크립트, 자바를 사용했습니다. 수준이 깊은 편이 아니고, 사실 규격에 엄격한 코딩이 힘들어서 상위 언어를 하고 싶은 마음이 있었습니다.

# 4. 제가 뒷자리여서.. 질문을 드리기가 죄송스럽습니다. 오시게 되면 동선이 길고, 제가 말하기엔 목소리가 커야 합니다. 혹시 단톡방이나 카톡을 이용해서 질문을 드리는 방법에 대해서 어떻게 생각하십니까?

# !편하게 해라.

### 아래 부터는 중요하지 않은 질문, 구글링으로 해결 할 수 있을 것 같은 질문 목록 ###

# 5. 파이썬에서 ' 와 " 의 차이가 궁금합니다.

# !없다.

# 6. 문자열 반복 기능에서, 이스케이프 문자 제거는 어떻게 합니까?
# https://colab.research.google.com/drive/1hA6YqotXcUaNEuzIoqrrECEKW9YHnG4Y#scrollTo=FD3NGzvEVImD&line=1&uniqifier=1

# !니가 프린트를 안써서 그렇다.

# 7. else 문에서 break 가 작동하지 않습니다. 어떻게 해야합니까?

# !작동할 수 없다. 그리고 니가 만든 코드에서는 필요하지 않다.

## 상담 후 조퇴, 방송에서 절대 나가면안됨?

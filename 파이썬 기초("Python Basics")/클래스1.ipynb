# %%
class Cat(object) :
  def __init__(self, data) -> None:
    print("초기화 완료") 
    self.age = data

cat_object = Cat(10)
print(f"고양이의 나이는: {cat_object.age}입니다.")
# Out:
# 초기화 완료
# 고양이의 나이는: 10입니다.

# %%
class Human(object):
    def __init__(self, age, name, address) -> None:
      print("초기화 완료") 
      self.age = age
      self.name = name
      self.address = address

human = Human(29, "안재욱", "서울역 노숙중")
human2 = Human(24, "Steve", "Yonge-Finch Station, Toronto, Canada")
print(f"나이는? {human.age}, 이름은? {human.name}, 주소는? {human.address}")
print(f"나이는? {human2.age}, 이름은? {human2.name}, 주소는? {human2.address}")

# 1번째 줄 class Human(object) 에서 "object" 의미 (해당 클래스 호출시 argument 를 오브젝트로 받는건가요?) ,
# 2번째 줄 def __init__(self, age, name, address) -> None: 에서 "self" 의 의미를 잘 모르겠습니다.
# self.age = age / 이 부분은 this. 개념과 같다고 보면될까요?
# Out:
# 초기화 완료
# 초기화 완료
# 나이는? 29, 이름은? 안재욱, 주소는? 서울역 노숙중
# 나이는? 24, 이름은? Steve, 주소는? Yonge-Finch Station, Toronto, Canada

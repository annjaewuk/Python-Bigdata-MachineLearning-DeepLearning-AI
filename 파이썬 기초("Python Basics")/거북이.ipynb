# %%
import turtle

turtle.forward(100)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-bea512168601> in <module>
#       1 import turtle
#       2
# ----> 3 turtle.forward(100)
#
# /usr/lib/python3.9/turtle.py in forward(distance)
#
# /usr/lib/python3.9/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3812                  visible=_CFG["visible"]):
#    3813         if Turtle._screen is None:
# -> 3814             Turtle._screen = Screen()
#    3815         RawTurtle.__init__(self, Turtle._screen,
#    3816                            shape=shape,
#
# /usr/lib/python3.9/turtle.py in Screen()
#    3662     else return the existing one."""
#    3663     if Turtle._screen is None:
# -> 3664         Turtle._screen = _Screen()
#    3665     return Turtle._screen
#    3666
#
# /usr/lib/python3.9/turtle.py in __init__(self)
# ...

# %%
sudo apt-get install xvfb
xvfb-run python3 your_script.py
# Out:
#   File "<ipython-input-2-93b8c1448c59>", line 1
#     sudo apt-get install xvfb
#          ^
# SyntaxError: invalid syntax

# %%
# !pip install ColabTurtle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7656 sha256=3144a777f828a831b688e23c7216912a3e462e27520ee66dad9241505df9be4a
#   Stored in directory: /root/.cache/pip/wheels/a8/ab/ce/4aca5e858d2561104f45e6164390067231381836678b908064
# Successfully built ColabTurtle
# ...

# %%
import ColabTurtle.Turtle as t
t.initializeTurtle()
t.shape('turtle')
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
for i in range(5):
  t.forward(10)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="240.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="240.0" x2="400.0" y2="230.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="230.0" x2="400.0" y2="220.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="220.0" x2="400.0" y2="210.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="210.0" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,200.0) translate(382.0, 182.0)">
# ...

# %%
def rectangle_turtle():
  t.initializeTurtle()
  t.shape('turtle')
  for i in range(4):
    t.right(90)
    t.forward(120)
     

rectangle_turtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="520.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="520.0" y1="250.0" x2="520.0" y2="370.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="520.0" y1="370.0" x2="400.0" y2="370.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="370.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

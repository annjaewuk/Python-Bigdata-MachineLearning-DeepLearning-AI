# %%
# !pip install cx_Oracle
# !apt-get install libaio1
# !apt-get install alien
# !alien -i /content/instantclient-basic-linux.x64-21.10.0.0.0dbru.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libaio1 is already the newest version (0.3.112-5).
# 0 upgraded, 0 newly installed, 0 to remove and 26 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   autopoint cpio debhelper debugedit dh-autoreconf dh-strip-nondeterminism dwz
#   gettext gettext-base intltool-debian libarchive-cpio-perl
#   libarchive-zip-perl libcroco3 libdebhelper-perl libdw1
#   libfile-stripnondeterminism-perl liblua5.2-0 libmail-sendmail-perl librpm8
#   librpmbuild8 librpmio8 librpmsign8 libsub-override-perl
#   libsys-hostname-long-perl libtool po-debconf rpm rpm-common rpm2cpio
# Suggested packages:
#   lintian libarchive1 dh-make rpm-i18n gettext-doc libasprintf-dev
# ...

# %%
# !pip install cx_Oracle
import cx_Oracle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python -m pip install cx_Oracle --upgrade --user
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
connection = cx_Oracle.connect(user="system", password="admin1234", dsn="localhost/xe")
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-16-c599a78579f6> in <cell line: 1>()
# ----> 1 connection = cx_Oracle.connect(user="system", password="admin1234", dsn="localhost/xe")
#
# DatabaseError: DPI-1047: Cannot locate a 64-bit Oracle Client library: "libclntsh.so: cannot open shared object file: No such file or directory". See https://cx-oracle.readthedocs.io/en/latest/user_guide/installation.html for help

# %%
# !pip install cx_Oracle #install Oracle client library
# !apt install alien
# !alien -i /content/drive/MyDrive/lib/oracle-instantclient19.3-basiclite-19.3.0.0.0-1.x86_64.rpm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.2/888.2 kB 15.2 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   autopoint cpio debhelper debugedit dh-autoreconf dh-strip-nondeterminism dwz
#   gettext gettext-base intltool-debian libarchive-cpio-perl
#   libarchive-zip-perl libcroco3 libdebhelper-perl libdw1
#   libfile-stripnondeterminism-perl liblua5.2-0 libmail-sendmail-perl librpm8
#   librpmbuild8 librpmio8 librpmsign8 libsub-override-perl
#   libsys-hostname-long-perl libtool po-debconf rpm rpm-common rpm2cpio
# Suggested packages:
#   lintian libarchive1 dh-make rpm-i18n gettext-doc libasprintf-dev
#   libgettextpo-dev libtool-doc gcj-jdk libmail-box-perl python elfutils
#   rpmlint rpm2html
# The following NEW packages will be installed:
# ...

# %%
import cx_Oracle

# %%
# 데이터베이스 연결 정보
host = "192.168.10.125"
port = 1521
sid = "xe"
username = "system"
password = "admin"

# 데이터베이스 연결 생성
dsn = cx_Oracle.makedsn(host, port, sid=sid)
print(dsn)
connection = cx_Oracle.connect(username, password, dsn)

# 데이터베이스 연결 테스트
print(connection.version)
# Out:
# (DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=192.168.10.125)(PORT=1521))(CONNECT_DATA=(SID=xe)))
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-14-19fb4ff9b41a> in <cell line: 11>()
#       9 dsn = cx_Oracle.makedsn(host, port, sid=sid)
#      10 print(dsn)
# ---> 11 connection = cx_Oracle.connect(username, password, dsn)
#      12
#      13 # 데이터베이스 연결 테스트
#
# DatabaseError: ORA-12170: TNS:Connect timeout occurred

# %%
# !unzip /content/영화추천시스템패키지.zip
# Out:
# Archive:  /content/영화추천시스템패키지.zip
#   inflating: collaborate_filtering.py
#   inflating: compute_score.py
#   inflating: rate_23.json
#   inflating: recomend_movie.py

# %%
# !python recomend_movie.py --user 'Chris Duncan' --jsonfile '/content/rate_23.json'
# Out:
# movie recommendations for Chris Duncan
# 0 : Vertigo
# 1 : Scarface
# 2 : Goodfellas
# 3 : Roman Holiday
